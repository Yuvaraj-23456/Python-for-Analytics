# %% [markdown]
# Q1) Import required libraries and read the dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/bhara/Downloads/honeyproduction.csv")

# %%
data
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %% [markdown]
# Q2) Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
data.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
data.tail()
# Out:
#     state   numcol  yieldpercol  totalprod     stocks  priceperlb  prodvalue  \
# 621    VA   4000.0           41   164000.0    23000.0        3.77   618000.0
# 622    WA  62000.0           41  2542000.0  1017000.0        2.38  6050000.0
# 623    WV   6000.0           48   288000.0    95000.0        2.91   838000.0
# 624    WI  60000.0           69  4140000.0  1863000.0        2.05  8487000.0
# 625    WY  50000.0           51  2550000.0   459000.0        1.87  4769000.0
#
#      year
# 621  2012
# 622  2012
# 623  2012
# 624  2012
# 625  2012

# %%
data.shape
# Out:
# (626, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %%
data.describe()
# Out:
#               numcol  yieldpercol     totalprod        stocks  priceperlb  \
# count     626.000000   626.000000  6.260000e+02  6.260000e+02  626.000000
# mean    60284.345048    62.009585  4.169086e+06  1.318859e+06    1.409569
# std     91077.087231    19.458754  6.883847e+06  2.272964e+06    0.638599
# min      2000.000000    19.000000  8.400000e+04  8.000000e+03    0.490000
# 25%      9000.000000    48.000000  4.750000e+05  1.430000e+05    0.932500
# 50%     26000.000000    60.000000  1.533000e+06  4.395000e+05    1.360000
# 75%     63750.000000    74.000000  4.175250e+06  1.489500e+06    1.680000
# max    510000.000000   136.000000  4.641000e+07  1.380000e+07    4.150000
#
#           prodvalue         year
# count  6.260000e+02   626.000000
# mean   4.715741e+06  2004.864217
# std    7.976110e+06     4.317306
# min    1.620000e+05  1998.000000
# 25%    7.592500e+05  2001.000000
# 50%    1.841500e+06  2005.000000
# 75%    4.703250e+06  2009.000000
# ...

# %% [markdown]
# Q3) Display the percentage distribution of the data in each year using the pie chart.

# %%
Each_year = data.groupby('year').size()/len(data)*100
plt.figure(figsize=(9,9))
plt.pie(Each_year, labels=Each_year.index, autopct='%1.1f%%')
plt.title('Percentage Distribution of Data in Each Year')
plt.show()

# %% [markdown]
# Q4) Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
plt.figure(figsize=(9,9))
sns.distplot(data['priceperlb'])
plt.title("distribution of the variable (price per lb) using displot")
plt.show()
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_25704\3010884577.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['priceperlb'])

# %% [markdown]
# By seeing the above histrogram,the skweness towards the right side.In the range of 1 and2 the density can reach above 0.8.

# %% [markdown]
# Q5) Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
plt.figure(figsize=(7,8))
plt.scatter(data['numcol'], data['prodvalue'],color = "tan")
plt.xlabel('Number of Colonies')
plt.ylabel('Production Value')
plt.title('Relationship between Number of Colonies and Production Value using a Scatter Plot.')
plt.show()

# %% [markdown]
# By seeing the above chart, it is positively correlated each other. When the number of colnoies increases, the production also increases.

# %% [markdown]
# Q6) Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
plt.figure(figsize=(7,8))
sns.boxplot(x='year', y='prodvalue', data=data)
plt.title('Relationship between Year and Prodvalue')
plt.show()

# %% [markdown]
# Q7) Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences.

# %%
sns.pairplot(data, vars=['numcol', 'yieldpercol', 'totalprod', 'prodvalue', 'year'], hue='year')
# Out:
# C:\Users\bhara\anaconda3\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Q8) Display the correlation values using a plot and add your inferences.

# %%
data_subset = data[['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']]
corr_matrix = data_subset.corr()
sns.heatmap(corr_matrix, annot=True)
plt.title("Correlation Matrix. Heat Map")
plt.show()

# %%
for col1 in corr_matrix.columns:
    for col2 in corr_matrix.columns:
        if col1 != col2:
            corr_value = corr_matrix.loc[col1, col2]
            if corr_value > 0.7:
                print(f"There is a strong positive correlation between {col1} and {col2}.")
            elif corr_value < -0.7:
                print(f"There is a strong negative correlation between {col1} and {col2}.")
            elif 0.3 < corr_value < 0.7:
                print(f"There is a moderate positive correlation between {col1} and {col2}.")
            elif -0.7 < corr_value < -0.3:
                print(f"There is a moderate negative correlation between {col1} and {col2}.")
            else:
                print(f"There is a weak or no correlation between {col1} and {col2}.")
# Out:
# There is a weak or no correlation between numcol and yieldpercol.
# There is a strong positive correlation between numcol and totalprod.
# There is a strong positive correlation between numcol and stocks.
# There is a weak or no correlation between numcol and priceperlb.
# There is a strong positive correlation between numcol and prodvalue.
# There is a weak or no correlation between yieldpercol and numcol.
# There is a moderate positive correlation between yieldpercol and totalprod.
# There is a moderate positive correlation between yieldpercol and stocks.
# There is a moderate negative correlation between yieldpercol and priceperlb.
# There is a weak or no correlation between yieldpercol and prodvalue.
# There is a strong positive correlation between totalprod and numcol.
# There is a moderate positive correlation between totalprod and yieldpercol.
# There is a strong positive correlation between totalprod and stocks.
# ...
